# %%
import warnings
warnings.filterwarnings("always")
warnings.filterwarnings("ignore")

# %%
import os
import numpy as np
import pandas as pd

# %%
covid_train_list = "Data-split/COVID/trainCT_COVID.csv"
covid_val_list = "Data-split/COVID/valCT_COVID.csv"
covid_test_list = "Data-split/COVID/testCT_COVID.csv"

noncovid_train_list = "Data-split/NonCOVID/trainCT_NonCOVID.csv"
noncovid_val_list = "Data-split/NonCOVID/valCT_NonCOVID.csv"
noncovid_test_list = "Data-split/NonCOVID/testCT_NonCOVID.csv"

# %% [markdown]
# # COVID

# %%
covid_train_df = pd.read_csv(covid_train_list)
print(covid_train_df.head())
# Out:
#                           filename  Unnamed: 1
# 0    2020.01.24.919183-p27-132.png         NaN
# 1    2020.01.24.919183-p27-133.png         NaN
# 2    2020.01.24.919183-p27-134.png         NaN
# 3    2020.01.24.919183-p27-135.png         NaN
# 4  2020.02.10.20021584-p6-52%0.png         NaN

# %%
covid_train_df.drop("Unnamed: 1", axis = 1, inplace = True)
covid_train_df
# Out:
#                                 filename
# 0          2020.01.24.919183-p27-132.png
# 1          2020.01.24.919183-p27-133.png
# 2          2020.01.24.919183-p27-134.png
# 3          2020.01.24.919183-p27-135.png
# 4        2020.02.10.20021584-p6-52%0.png
# 5        2020.02.10.20021584-p6-52%1.png
# 6       2020.02.10.20021584-p6-52%10.png
# 7       2020.02.10.20021584-p6-52%11.png
# 8       2020.02.10.20021584-p6-52%12.png
# 9       2020.02.10.20021584-p6-52%13.png
# 10      2020.02.10.20021584-p6-52%14.png
# 11      2020.02.10.20021584-p6-52%15.png
# 12       2020.02.10.20021584-p6-52%2.png
# 13       2020.02.10.20021584-p6-52%3.png
# 14       2020.02.10.20021584-p6-52%4.png
# 15       2020.02.10.20021584-p6-52%5.png
# 16       2020.02.10.20021584-p6-52%6.png
# 17       2020.02.10.20021584-p6-52%7.png
# 18       2020.02.10.20021584-p6-52%8.png
# 19       2020.02.10.20021584-p6-52%9.png
# 20     2020.02.11.20021493-p16-109%0.png
# 21     2020.02.11.20021493-p16-109%1.png
# ...

# %%
covid_val_df = pd.read_csv(covid_val_list)
print(covid_val_df.head())
# Out:
#                           filename  Unnamed: 1
# 0  2020.03.13.20035212-p23-155.png         NaN
# 1  2020.03.13.20035212-p23-156.png         NaN
# 2  2020.03.13.20035212-p23-157.png         NaN
# 3  2020.03.13.20035212-p23-158.png         NaN
# 4  2020.03.13.20035212-p23-159.png         NaN

# %%
covid_val_df.drop("Unnamed: 1", axis = 1, inplace = True)
covid_val_df
# Out:
#                               filename
# 0      2020.03.13.20035212-p23-155.png
# 1      2020.03.13.20035212-p23-156.png
# 2      2020.03.13.20035212-p23-157.png
# 3      2020.03.13.20035212-p23-158.png
# 4      2020.03.13.20035212-p23-159.png
# 5      2020.03.13.20035212-p23-160.png
# 6      2020.03.13.20035212-p23-161.png
# 7      2020.03.13.20035212-p23-162.png
# 8      2020.03.13.20035212-p23-163.png
# 9      2020.03.16.20035105-p6-64-1.png
# 10     2020.03.16.20035105-p6-64-2.png
# 11     2020.03.16.20035105-p6-64-3.png
# 12     2020.03.16.20035105-p6-64-4.png
# 13   2020.03.16.20036145-p19-128-1.png
# 14   2020.03.16.20036145-p19-128-2.png
# 15   2020.03.16.20036145-p19-128-3.png
# 16   2020.03.16.20036145-p19-128-4.png
# 17    2020.03.18.20038125-p15-54-2.png
# 18    2020.03.18.20038125-p15-54-4.png
# 19    2020.03.18.20038125-p15-54-5.png
# 20    2020.03.18.20038125-p15-54-6.png
# 21    2020.03.18.20038125-p16-56-1.png
# 22    2020.03.18.20038125-p16-56-2.png
# ...

# %%
covid_test_df = pd.read_csv(covid_test_list)
print(covid_test_df.head())
# Out:
#                            filename  Unnamed: 1
# 0  2020.03.22.20040782-p25-1542.png         NaN
# 1  2020.03.22.20040782-p25-1543.png         NaN
# 2  2020.03.22.20040782-p25-1544.png         NaN
# 3  2020.03.22.20040782-p25-1545.png         NaN
# 4  2020.03.22.20040782-p25-1546.png         NaN

# %%
covid_test_df.drop("Unnamed: 1", axis = 1, inplace = True)
covid_test_df
# Out:
#                                              filename
# 0                    2020.03.22.20040782-p25-1542.png
# 1                    2020.03.22.20040782-p25-1543.png
# 2                    2020.03.22.20040782-p25-1544.png
# 3                    2020.03.22.20040782-p25-1545.png
# 4                    2020.03.22.20040782-p25-1546.png
# 5                    2020.03.12.20034686-p17-91-1.png
# 6                    2020.03.12.20034686-p17-91-2.png
# 7                     2020.03.25.20037721-p27-172.png
# 8                     2020.03.25.20037721-p27-173.png
# 9                     2020.03.25.20037721-p27-174.png
# 10                    2020.03.25.20037721-p27-181.png
# 11                    2020.03.25.20037721-p27-182.png
# 12                    2020.03.25.20037721-p27-165.png
# 13                     2020.03.25.20043166-p17-78.png
# 14                     2020.03.25.20043166-p17-79.png
# 15                     2020.03.25.20043166-p17-80.png
# ...

# %% [markdown]
# # NonCOVID

# %%
noncovid_train_df = pd.read_csv(noncovid_train_list)
print(noncovid_train_df.head())
# Out:
#   filename  Unnamed: 1
# 0   14.png         NaN
# 1   15.png         NaN
# 2   33.png         NaN
# 3   43.png         NaN
# 4   44.png         NaN

# %%
noncovid_train_df.drop("Unnamed: 1", axis = 1, inplace = True)
noncovid_train_df
# Out:
#      filename
# 0      14.png
# 1      15.png
# 2      33.png
# 3      43.png
# 4      44.png
# 5      59.png
# 6      81.png
# 7      82.png
# 8     102.png
# 9     103.png
# 10    104.png
# 11    114.png
# 12    115.png
# 13    116.png
# 14    117.png
# 15    118.png
# 16    120.png
# 17    158.png
# 18    171.png
# 19    174.png
# 20    226.png
# 21    227.png
# 22    294.png
# 23    354.png
# 24    361.png
# 25    378.png
# 26    381.png
# 27    382.png
# 28    383.png
# 29    385.png
# ..        ...
# 204    77.jpg
# 205    78.jpg
# 206    79.jpg
# 207  80%0.jpg
# 208  80%1.jpg
# 209  81%0.jpg
# 210  81%1.jpg
# 211  81%2.jpg
# 212  81%3.jpg
# 213  82%0.jpg
# 214  82%1.jpg
# 215  82%2.jpg
# 216  82%3.jpg
# 217  83%0.jpg
# 218  83%1.jpg
# 219  83%2.jpg
# 220  83%3.jpg
# 221  84%0.jpg
# 222  84%1.jpg
# 223  84%2.jpg
# 224  84%3.jpg
# 225  85%0.jpg
# 226  85%1.jpg
# 227    86.jpg
# 228    88.jpg
# 229  89%2.jpg
# 230  89%3.jpg
# 231    90.jpg
# 232  91%0.jpg
# 233  91%1.jpg
#
# ...

# %%
noncovid_val_df = pd.read_csv(noncovid_val_list)
print(noncovid_val_df.head())
# Out:
#   filename  Unnamed: 1
# 0   23.png         NaN
# 1   24.png         NaN
# 2   25.png         NaN
# 3   26.png         NaN
# 4  412.png         NaN

# %%
noncovid_val_df.drop("Unnamed: 1", axis = 1, inplace = True)
noncovid_val_df
# Out:
#     filename
# 0     23.png
# 1     24.png
# 2     25.png
# 3     26.png
# 4    412.png
# 5    413.png
# 6    414.png
# 7    486.png
# 8    487.png
# 9    709.png
# 10   753.png
# 11   754.png
# 12   887.png
# 13   889.png
# 14   890.png
# 15  1070.png
# 16  1071.png
# 17  1072.png
# 18  1164.png
# 19  1261.png
# 20  1262.png
# 21  1263.png
# 22  1264.png
# 23  1297.png
# 24  1298.png
# 25  1428.png
# 26  1876.png
# 27  1877.png
# 28    20.jpg
# 29  21%0.jpg
# 30  21%1.jpg
# 31  22%0.jpg
# 32  22%1.jpg
# 33  25%0.jpg
# 34  25%1.jpg
# 35  25%2.jpg
# 36  25%3.jpg
# 37  26%0.jpg
# 38  26%1.jpg
# 39  26%2.jpg
# 40  26%3.jpg
# 41    27.jpg
# 42    28.jpg
# 43  29%0.jpg
# 44  29%1.jpg
# 45  29%2.jpg
# 46  29%3.jpg
# 47  30%0.jpg
# 48  30%1.jpg
# 49  30%2.jpg
# 50  30%3.jpg
# 51  30%4.jpg
# 52  30%5.jpg
# 53    31.jpg
# 54  32%0.jpg
# 55  32%1.jpg
# 56  33%0.jpg
# 57  33%1.jpg

# %%
noncovid_test_df = pd.read_csv(noncovid_test_list)
print(noncovid_test_df.head())
# Out:
#   filename  Unnamed: 1
# 0  112.png         NaN
# 1  166.png         NaN
# 2  167.png         NaN
# 3  176.png         NaN
# 4  177.png         NaN

# %%
noncovid_test_df.drop("Unnamed: 1", axis = 1, inplace = True)
noncovid_test_df
# Out:
#      filename
# 0     112.png
# 1     166.png
# 2     167.png
# 3     176.png
# 4     177.png
# 5     452.png
# 6     583.png
# 7     584.png
# 8     590.png
# 9     591.png
# 10    592.png
# 11    658.png
# 12    660.png
# 13    661.png
# 14    662.png
# 15    663.png
# 16    848.png
# 17    849.png
# 18    969.png
# 19    996.png
# 20    997.png
# 21   1046.png
# 22   1047.png
# 23   1048.png
# 24   1049.png
# 25   1050.png
# 26   1078.png
# 27   1079.png
# 28   1098.png
# 29   1210.png
# ..        ...
# 75   18%0.jpg
# 76   18%1.jpg
# 77   18%2.jpg
# 78   18%3.jpg
# 79   19%0.jpg
# 80   19%1.jpg
# 81    2%0.jpg
# 82    2%1.jpg
# 83    2%2.jpg
# 84    2%3.jpg
# 85      3.jpg
# 86    4%1.jpg
# 87    4%3.jpg
# 88    4%5.jpg
# 89    4%7.jpg
# 90    5%0.jpg
# 91    5%1.jpg
# 92    5%2.jpg
# 93    5%3.jpg
# 94    5%4.jpg
# 95    5%5.jpg
# 96    5%6.jpg
# 97    5%7.jpg
# 98    6%0.jpg
# 99    6%1.jpg
# 100   6%2.jpg
# 101   6%3.jpg
# 102     7.jpg
# 103     8.jpg
# 104     9.jpg
#
# ...

# %% [markdown]
# # Move files

# %%
import shutil

src = "Images-processed/CT_NonCOVID/"
dst = "data/test/noncovid/"

col_noncovid_test_list = noncovid_test_df['filename'].tolist()

for file in col_noncovid_test_list:
    srcname = os.path.join(src, file)
    dstname = os.path.join(dst, file)
#     print(srcname)
#     print(dstname)
    shutil.move(srcname, dstname)
